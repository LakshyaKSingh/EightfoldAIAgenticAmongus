# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(pd.read_csv("dataset.csv"))

# %%
df.sample(10)
# Out:
#       profile_age_days  applications_7d  applications_30d  \
# 5237                73                5                 7
# 9259              1980                5                15
# 701               1763                2                 3
# 9531               110                2                12
# 2681              2414                1                12
# 1595              2098                3                19
# 18                 703                1                 6
# 9966               175                2                 3
# 9786              2831                5                19
# 1739               682                1                 7
#
#       avg_applications_30d  app_to_avg_ratio  skills_count  \
# 5237                9.7074            0.0240            21
# 9259                7.3633            0.0676            38
# 701                 1.2268            0.0794             5
# 9531                1.0747            0.3610             5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   profile_age_days         10000 non-null  int64
#  1   applications_7d          10000 non-null  int64
#  2   applications_30d         10000 non-null  int64
#  3   avg_applications_30d     10000 non-null  float64
#  4   app_to_avg_ratio         10000 non-null  float64
#  5   skills_count             10000 non-null  int64
#  6   endorsements_count       10000 non-null  int64
#  7   experience_years         10000 non-null  float64
#  8   skills_to_exp_ratio      10000 non-null  float64
#  9   institution_risk_score   10000 non-null  float64
#  10  company_risk_score       10000 non-null  float64
#  11  gpa_anomaly_score        10000 non-null  float64
#  12  tenure_gap_months        10000 non-null  float64
#  13  avg_tenure_months        10000 non-null  float64
# ...

# %%
df.describe()
# Out:
#        profile_age_days  applications_7d  applications_30d  \
# count        10000.0000     10000.000000      10000.000000
# mean          1820.4377         4.627900         16.203900
# std           1053.3482        11.110787         30.977493
# min              1.0000         0.000000          0.000000
# 25%            912.0000         1.000000          8.000000
# 50%           1812.5000         4.000000         13.000000
# 75%           2728.0000         6.000000         18.000000
# max           3649.0000       149.000000        448.000000
#
#        avg_applications_30d  app_to_avg_ratio  skills_count  \
# count          10000.000000      10000.000000  10000.000000
# mean               4.511767          0.225676     23.747700
# std                4.081290          0.672068     17.863084
# min                0.100000          0.000000      1.000000
# 25%                1.928825          0.058800     11.000000
# 50%                3.284400          0.118400     18.000000
# ...

# %%
df.corr()
# Out:
#                          profile_age_days  applications_7d  applications_30d  \
# profile_age_days                 1.000000        -0.009963         -0.010952
# applications_7d                 -0.009963         1.000000          0.882977
# applications_30d                -0.010952         0.882977          1.000000
# avg_applications_30d             0.024088        -0.017007         -0.013925
# app_to_avg_ratio                -0.000629         0.613309          0.703240
# skills_count                     0.004396        -0.004919         -0.003920
# endorsements_count              -0.004563         0.000661          0.001770
# experience_years                 0.000321        -0.009175         -0.008452
# skills_to_exp_ratio             -0.145008        -0.002589         -0.003465
# institution_risk_score           0.005835        -0.016284         -0.008359
# company_risk_score               0.008226        -0.010460         -0.009321
# ...
